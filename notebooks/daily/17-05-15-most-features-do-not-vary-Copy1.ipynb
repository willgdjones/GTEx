# %%
import os
import sys
sys.path = ['/nfs/gns/homes/willj/anaconda3/envs/GTEx/lib/python3.5/site-packages'] + sys.path
GTEx_directory = '/hps/nobackup/research/stegle/users/willj/GTEx'
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import h5py
from scipy.stats import pearsonr
import statsmodels.stats.multitest as smm
import pickle
import pylab as PL

# %%
with h5py.File(GTEx_directory + '/data/new_retrained_inceptionet_aggregations.hdf5','r') as f:
    feat = f['lung']['256']['mean'].value

# %%
PL.figure(None,[20,5])
PL.imshow(feat, interpolation="None", cmap=PL.get_cmap("coolwarm"))
PL.title("Mean feature for size 256")
PL.xlabel("Features"); PL.ylabel("Individuals")

# %%
PL.figure(None,[10,10])
PL.imshow(feat[0:50,0:50], interpolation="None", cmap=PL.get_cmap("coolwarm"))
PL.title("Mean feature for size 256")
PL.xlabel("Features"); PL.ylabel("Individuals")
PL.colorbar()
